# %% [markdown]
# # Complex Bayesian Network notebook

# %% [markdown]
# #### Import dependencies

# %%
# Import dependencies
#%pip install pgmpy
#%pip install tabulate
#%pip install pandas
#%pip install networkx
#%pip install matplotlib

# %% [markdown]
# #### Load libraries

# %%
# Load libraries
import pgmpy as pg
import tabulate as tb
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data import and cleaning

# %% [markdown]
# #### Import BigPerf data

# %%
# Import data
df = pd.read_csv("C:\\Users\\Keir McGlinn-Shaw\\Documents\\Stage-3\\Dissertation\\Data\\Use\\BigPerfMetrics.csv")

df.head()
# Out:
#          Block_ID  HDFS_BW  HDFSTranmissionTime  Mapper_ID  Mapper_VM_MIPS  \
# 0  HDFS_Block_208    11.81                80.63  mapper207          652289
# 1  HDFS_Block_208    11.81                80.63  mapper207          652289
# 2  HDFS_Block_208    11.81                80.63  mapper207          652289
# 3  HDFS_Block_208    11.81                80.63  mapper207          652289
# 4  HDFS_Block_208    11.81                80.63  mapper207          652289
#
#    MapExecutionTime   MapperBW  MapperTransmissionTime Reducer_ID  \
# 0             765.49     30.00                    2.53   reducer0
# 1             765.49     30.00                    2.53   reducer1
# 2             765.49     16.76                    3.25   reducer2
# 3             765.49     16.76                    3.25   reducer3
# 4             765.49     18.41                    4.16   reducer4
#
#    Reducer_VM_MIPS  ReducerExecutionTime   ReducerBW  ReducerTransmissionTime  \
# 0           341739                    480       3.80                   250.14
# 1           150000                    120      50.00                    18.99
# 2           382530                    480       4.48                   212.22
# 3           150000                    120       5.88                   161.57
# 4           457419                    480       5.88                   161.53
#
#          Block_ID.1  Block_BW  BlockTransmissionTime  TransactionTime
# 0  reducer0_Block_1       0.0                   0.00          1578.79
# 1  reducer1_Block_1      50.0                  20.00          1007.64
# 2  reducer2_Block_1       3.7                 270.02          1811.61
# 3  reducer3_Block_1       3.7                 270.02          1400.96
# 4  reducer4_Block_1       3.7                 270.02          1761.83

# %% [markdown]
# #### Clean data of unwanted variables and missing values

# %%
# Clean data
df.dropna()

df.drop(labels=['Block_ID', 'Mapper_ID', 'Reducer_ID', 'Block_ID.1'], axis=1, inplace=True)

df.head()
# Out:
#    HDFS_BW  HDFSTranmissionTime  Mapper_VM_MIPS  MapExecutionTime   MapperBW  \
# 0    11.81                80.63          652289             765.49     30.00
# 1    11.81                80.63          652289             765.49     30.00
# 2    11.81                80.63          652289             765.49     16.76
# 3    11.81                80.63          652289             765.49     16.76
# 4    11.81                80.63          652289             765.49     18.41
#
#    MapperTransmissionTime  Reducer_VM_MIPS  ReducerExecutionTime   ReducerBW  \
# 0                    2.53           341739                    480       3.80
# 1                    2.53           150000                    120      50.00
# 2                    3.25           382530                    480       4.48
# 3                    3.25           150000                    120       5.88
# 4                    4.16           457419                    480       5.88
#
#    ReducerTransmissionTime  Block_BW  BlockTransmissionTime  TransactionTime
# 0                   250.14       0.0                   0.00          1578.79
# 1                    18.99      50.0                  20.00          1007.64
# 2                   212.22       3.7                 270.02          1811.61
# 3                   161.57       3.7                 270.02          1400.96
# 4                   161.53       3.7                 270.02          1761.83

# %% [markdown]
# #### Rename columns to better fit in drawn charts and for ease of use

# %%
# Rename column headers to abbreviations

nodes = ['HBW', 'HTT', 'MMIPS', 'MET', 'MBW', 'MTT', 'RMIPS', 'RET', 'RBW', 'RTT', 'BBW', 'BTT', 'TT']

df.columns = nodes

df.head(10)
# Out:
#      HBW    HTT   MMIPS     MET    MBW   MTT   RMIPS  RET     RBW     RTT  \
# 0  11.81  80.63  652289  765.49  30.00  2.53  341739  480    3.80  250.14
# 1  11.81  80.63  652289  765.49  30.00  2.53  150000  120   50.00   18.99
# 2  11.81  80.63  652289  765.49  16.76  3.25  382530  480    4.48  212.22
# 3  11.81  80.63  652289  765.49  16.76  3.25  150000  120    5.88  161.57
# 4  11.81  80.63  652289  765.49  18.41  4.16  457419  480    5.88  161.53
# 5  11.81  80.63  652289  765.49  18.41  4.16  150000  120    6.98  136.24
# 6  11.81  80.63  652289  765.49  18.41  4.16  563904  480    3.80  250.14
# 7  11.81  80.63  652289  765.49  18.41  4.16  150000  120  150.00    6.33
# 8  11.81  80.63  652289  765.49  18.41  4.16  430890  480    3.80  250.14
# 9  11.81  80.63  652289  765.49  18.41  4.16  150000  120  150.00    6.33
#
#     BBW     BTT       TT
# 0   0.0    0.00  1578.79
# 1  50.0   20.00  1007.64
# 2   3.7  270.02  1811.61
# 3   3.7  270.02  1400.96
# 4   3.7  270.02  1761.83
# 5   3.7  270.02  1376.54
# 6   3.7  270.02  1850.44
# 7   3.7  270.02  1246.63
# 8   3.7  270.02  1850.44
# 9   3.7  270.02  1246.63

# %% [markdown]
# #### Define funtion to discretise data into three catagories

# %%
'''
Splits data into three bins of equal size using: https://pandas.pydata.org/docs/reference/api/pandas.cut.html
'''
def split_tertiles(df):
    tertile_labels = ['Low', 'Medium', 'High']

    tert_df = pd.DataFrame()

    for column_name in df:
        tert_df[column_name] = pd.cut(df[column_name], 3, labels=tertile_labels, ordered=True)

    # Change type of values stored in dataframe to avoid errors arrising from using the Category type when the dataframe is fed into the pgmpy.metrics.metrics correlation_score function
    tert_df = tert_df.astype('object')

    return tert_df

# %% [markdown]
# #### Descritise data into catagories

# %%
# Discretise BigPerf dataset
cat_df = split_tertiles(df)

cat_df.head()
# Out:
#     HBW  HTT MMIPS  MET     MBW  MTT   RMIPS   RET  RBW     RTT   BBW   BTT  \
# 0  High  Low   Low  Low    High  Low  Medium  High  Low    High   Low   Low
# 1  High  Low   Low  Low    High  Low     Low   Low  Low     Low  High   Low
# 2  High  Low   Low  Low  Medium  Low  Medium  High  Low    High   Low  High
# 3  High  Low   Low  Low  Medium  Low     Low   Low  Low  Medium   Low  High
# 4  High  Low   Low  Low  Medium  Low    High  High  Low  Medium   Low  High
#
#        TT
# 0     Low
# 1     Low
# 2  Medium
# 3     Low
# 4  Medium

# %%
from pgmpy.estimators import TreeSearch

# learn graph structure
est = TreeSearch(cat_df, root_node="HBW")
dag = est.estimate(estimator_type="tan", class_node="TT")
# Out:
# Building tree: 100%|██████████| 66/66.0 [00:00<00:00, 390.54it/s]

# %%
G = nx.DiGraph()
G.add_edges_from(dag.edges)
G.add_nodes_from(dag.nodes)
pos = nx.kamada_kawai_layout(G)
nx.draw(G, pos=pos, with_labels=True, arrowsize=30, node_size=800, alpha=0.7, font_weight="bold")  # Draw the original graph

# %%
from pgmpy.estimators import BayesianEstimator, MaximumLikelihoodEstimator
from pgmpy.models import BayesianModel

model = BayesianModel(dag.edges)

model.fit(data=cat_df, estimator=BayesianEstimator, prior_type='dirichlet', pseudo_counts=0.1)

model.get_cpds()
# Out:
# [<TabularCPD representing P(HBW:2 | TT:3) at 0x23b345740d0>,
#  <TabularCPD representing P(HTT:2 | HBW:2, TT:3) at 0x23b34617d60>,
#  <TabularCPD representing P(MTT:3 | HTT:2, TT:3) at 0x23b34617f10>,
#  <TabularCPD representing P(MBW:3 | MTT:3, TT:3) at 0x23b346172b0>,
#  <TabularCPD representing P(MMIPS:3 | MTT:3, TT:3) at 0x23b34617c70>,
#  <TabularCPD representing P(BTT:2 | MBW:3, TT:3) at 0x23b34617550>,
#  <TabularCPD representing P(MET:3 | MMIPS:3, TT:3) at 0x23b34617a90>,
#  <TabularCPD representing P(BBW:2 | BTT:2, TT:3) at 0x23b34627c40>,
#  <TabularCPD representing P(RTT:3 | BBW:2, TT:3) at 0x23b34627f10>,
#  <TabularCPD representing P(RMIPS:3 | RTT:3, TT:3) at 0x23b34627340>,
#  <TabularCPD representing P(RBW:2 | RTT:3, TT:3) at 0x23b34627bb0>,
#  <TabularCPD representing P(RET:2 | RMIPS:3, TT:3) at 0x23b34627e80>,
#  <TabularCPD representing P(TT:3) at 0x23b346278b0>]

# %%
print(f'Check model: {model.check_model()}\n')
for cpd in model.get_cpds():
    print(f'CPT of {cpd.variable}:')
    print(cpd, '\n')
# Out:
# Check model: True
#
# CPT of HBW:
# +-----------+---------------------+--------------------+--------------------+
# | TT        | TT(High)            | TT(Low)            | TT(Medium)         |
# +-----------+---------------------+--------------------+--------------------+
# | HBW(High) | 0.39947310038824185 | 0.7585807050092764 | 0.5785189453969168 |
# +-----------+---------------------+--------------------+--------------------+
# | HBW(Low)  | 0.6005268996117582  | 0.2414192949907235 | 0.4214810546030831 |
# +-----------+---------------------+--------------------+--------------------+
#
# CPT of HTT:
# +-----------+------------------------+-----------------------+-----------------------+------------------------+---------------------+----------------------+
# | HBW       | HBW(High)              | HBW(High)             | HBW(High)             | HBW(Low)               | HBW(Low)            | HBW(Low)             |
# +-----------+------------------------+-----------------------+-----------------------+------------------------+---------------------+----------------------+
# | TT        | TT(High)               | TT(Low)               | TT(Medium)            | TT(High)               | TT(Low)             | TT(Medium)           |
# +-----------+------------------------+-----------------------+-----------------------+------------------------+---------------------+----------------------+
# | HTT(High) | 0.00034698126301179735 | 0.0003056234718826406 | 0.0001245019920318725 | 0.9997691597414589     | 0.9414587332053743  | 0.9793233082706767   |
# +-----------+------------------------+-----------------------+-----------------------+------------------------+---------------------+----------------------+
# | HTT(Low)  | 0.9996530187369881     | 0.9996943765281173    | 0.999875498007968     | 0.00023084025854108956 | 0.05854126679462572 | 0.020676691729323307 |
# +-----------+------------------------+-----------------------+-----------------------+------------------------+---------------------+----------------------+
#
# CPT of MTT:
# +-------------+--------------------+---------------------+---------------------+----------------------+---------------------+--------------------+
# | HTT         | HTT(High)          | HTT(High)           | HTT(High)           | HTT(Low)             | HTT(Low)            | HTT(Low)           |
# +-------------+--------------------+---------------------+---------------------+----------------------+---------------------+--------------------+
# | TT          | TT(High)           | TT(Low)             | TT(Medium)          | TT(High)             | TT(Low)             | TT(Medium)         |
# +-------------+--------------------+---------------------+---------------------+----------------------+---------------------+--------------------+
# | MTT(High)   | 0.3348719132240942 | 0.42828077314343843 | 0.32286760858189434 | 0.9125910509885534   | 0.4323432343234323  | 0.737274622838219  |
# +-------------+--------------------+---------------------+---------------------+----------------------+---------------------+--------------------+
# | MTT(Low)    | 0.2033233325640434 | 0.18413021363173956 | 0.23390894819466249 | 0.0454387790496011   | 0.4473447344734473  | 0.1988225193180424 |
# +-------------+--------------------+---------------------+---------------------+----------------------+---------------------+--------------------+
# | MTT(Medium) | 0.4618047542118625 | 0.3875890132248219  | 0.44322344322344326 | 0.041970169961845286 | 0.12031203120312031 | 0.0639028578437385 |
# +-------------+--------------------+---------------------+---------------------+----------------------+---------------------+--------------------+
#
# CPT of MBW:
# +-------------+------------------------+-----------------------+------------------------+---------------------+---------------------+---------------------+------------------------+-----------------------+------------------------+
# | MTT         | MTT(High)              | MTT(High)             | MTT(High)              | MTT(Low)            | MTT(Low)            | MTT(Low)            | MTT(Medium)            | MTT(Medium)           | MTT(Medium)            |
# +-------------+------------------------+-----------------------+------------------------+---------------------+---------------------+---------------------+------------------------+-----------------------+------------------------+
# | TT          | TT(High)               | TT(Low)               | TT(Medium)             | TT(High)            | TT(Low)             | TT(Medium)          | TT(High)               | TT(Low)               | TT(Medium)             |
# +-------------+------------------------+-----------------------+------------------------+---------------------+---------------------+---------------------+------------------------+-----------------------+------------------------+
# | MBW(High)   | 0.00024491795248591716 | 0.0005367686527106818 | 0.00012717792191275595 | 0.21816386969397827 | 0.6401673640167365  | 0.48970637867026656 | 0.00047103155911446074 | 0.0012771392081736912 | 0.00032647730982696696 |
# +-------------+------------------------+-----------------------+------------------------+---------------------+---------------------+---------------------+------------------------+-----------------------+------------------------+
# | MBW(Low)    | 0.999510164095028      | 0.9989264626945787    | 0.9997456441561744     | 0.6031589338598222  | 0.14405260011954574 | 0.31083361457981773 | 0.9990579368817711     | 0.9974457215836527    | 0.9993470453803459     |
# +-------------+------------------------+-----------------------+------------------------+---------------------+---------------------+---------------------+------------------------+-----------------------+------------------------+
# | MBW(Medium) | 0.00024491795248591716 | 0.0005367686527106818 | 0.00012717792191275595 | 0.1786771964461994  | 0.2157800358637179  | 0.19946000674991562 | 0.00047103155911446074 | 0.0012771392081736912 | 0.00032647730982696696 |
# +-------------+------------------------+-----------------------+------------------------+---------------------+---------------------+---------------------+------------------------+-----------------------+------------------------+
#
# CPT of MMIPS:
# +---------------+---------------------+-----------------------+---------------------+--------------------+---------------------+---------------------+---------------------+-----------------------+---------------------+
# | MTT           | MTT(High)           | MTT(High)             | MTT(High)           | MTT(Low)           | MTT(Low)            | MTT(Low)            | MTT(Medium)         | MTT(Medium)           | MTT(Medium)         |
# +---------------+---------------------+-----------------------+---------------------+--------------------+---------------------+---------------------+---------------------+-----------------------+---------------------+
# | TT            | TT(High)            | TT(Low)               | TT(Medium)          | TT(High)           | TT(Low)             | TT(Medium)          | TT(High)            | TT(Low)               | TT(Medium)          |
# +---------------+---------------------+-----------------------+---------------------+--------------------+---------------------+---------------------+---------------------+-----------------------+---------------------+
# | MMIPS(High)   | 0.6688709282390398  | 0.0005367686527106818 | 0.2964517359786341  | 0.5340572556762092 | 0.14405260011954574 | 0.32433344583192714 | 0.6081017428167688  | 0.0012771392081736912 | 0.20600718250081618 |
# +---------------+---------------------+-----------------------+---------------------+--------------------+---------------------+---------------------+---------------------+-----------------------+---------------------+
# | MMIPS(Low)    | 0.04677932892481018 | 0.7198067632850242    | 0.27355971003433804 | 0.1786771964461994 | 0.56246264196055    | 0.43570705366182927 | 0.13707018370230808 | 0.9974457215836527    | 0.6173685928827946  |
# +---------------+---------------------+-----------------------+---------------------+--------------------+---------------------+---------------------+---------------------+-----------------------+---------------------+
# | MMIPS(Medium) | 0.28434974283614983 | 0.2796564680622652    | 0.4299885539870279  | 0.2872655478775913 | 0.2934847579199044  | 0.23995950050624368 | 0.25482807348092323 | 0.0012771392081736912 | 0.17662422461638916 |
# +---------------+---------------------+-----------------------+---------------------+--------------------+---------------------+---------------------+---------------------+-----------------------+---------------------+
#
# CPT of BTT:
# +-----------+---------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+
# | MBW       | MBW(High)           | MBW(High)            | MBW(High)           | MBW(Low)            | MBW(Low)            | MBW(Low)            | MBW(Medium)         | MBW(Medium)        | MBW(Medium)         |
# +-----------+---------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+
# | TT        | TT(High)            | TT(Low)              | TT(Medium)          | TT(High)            | TT(Low)             | TT(Medium)          | TT(High)            | TT(Low)            | TT(Medium)          |
# +-----------+---------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+
# | BTT(High) | 0.45495495495495497 | 0.028917910447761198 | 0.22796143250688708 | 0.9220493247210804  | 0.8192227619708536  | 0.901114676574903   | 0.9395604395604394  | 0.2790055248618784 | 0.47466216216216217 |
# +-----------+---------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+
# | BTT(Low)  | 0.545045045045045   | 0.9710820895522388   | 0.772038567493113   | 0.07795067527891955 | 0.18077723802914644 | 0.09888532342509712 | 0.06043956043956043 | 0.7209944751381215 | 0.5253378378378378  |
# +-----------+---------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+--------------------+---------------------+
#
# CPT of MET:
# +-------------+------------------------+----------------------+------------------------+-----------------------+------------------------+------------------------+-----------------------+----------------------+------------------------+
# | MMIPS       | MMIPS(High)            | MMIPS(High)          | MMIPS(High)            | MMIPS(Low)            | MMIPS(Low)             | MMIPS(Low)             | MMIPS(Medium)         | MMIPS(Medium)        | MMIPS(Medium)          |
# +-------------+------------------------+----------------------+------------------------+-----------------------+------------------------+------------------------+-----------------------+----------------------+------------------------+
# | TT          | TT(High)               | TT(Low)              | TT(Medium)             | TT(High)              | TT(Low)                | TT(Medium)             | TT(High)              | TT(Low)              | TT(Medium)             |
# +-------------+------------------------+----------------------+------------------------+-----------------------+------------------------+------------------------+-----------------------+----------------------+------------------------+
# | MET(High)   | 0.999561691869384      | 0.9917695473251028   | 0.99949018608208       | 0.0015082956259426853 | 0.00032647730982696696 | 0.00018751171948246765 | 0.0005017561465127949 | 0.000987166831194472 | 0.00021584286639326572 |
# +-------------+------------------------+----------------------+------------------------+-----------------------+------------------------+------------------------+-----------------------+----------------------+------------------------+
# | MET(Low)    | 0.00021915406530791145 | 0.004115226337448559 | 0.00025490695895997957 | 0.9969834087481148    | 0.9993470453803459     | 0.999624976561035      | 0.0005017561465127949 | 0.000987166831194472 | 0.00021584286639326572 |
# +-------------+------------------------+----------------------+------------------------+-----------------------+------------------------+------------------------+-----------------------+----------------------+------------------------+
# | MET(Medium) | 0.00021915406530791145 | 0.004115226337448559 | 0.00025490695895997957 | 0.0015082956259426853 | 0.00032647730982696696 | 0.00018751171948246765 | 0.9989964877069745    | 0.998025666337611    | 0.9995683142672135     |
# +-------------+------------------------+----------------------+------------------------+-----------------------+------------------------+------------------------+-----------------------+----------------------+------------------------+
#
# CPT of BBW:
# +-----------+------------------------+------------------------+-----------------------+-----------------------+---------------------+---------------------+
# | BTT       | BTT(High)              | BTT(High)              | BTT(High)             | BTT(Low)              | BTT(Low)            | BTT(Low)            |
# +-----------+------------------------+------------------------+-----------------------+-----------------------+---------------------+---------------------+
# | TT        | TT(High)               | TT(Low)                | TT(Medium)            | TT(High)              | TT(Low)             | TT(Medium)          |
# +-----------+------------------------+------------------------+-----------------------+-----------------------+---------------------+---------------------+
# | BBW(High) | 0.00015262515262515263 | 0.00040128410914927774 | 8.863676653075698e-05 | 0.0015105740181268886 | 0.9281009879253568  | 0.32705611068408913 |
# +-----------+------------------------+------------------------+-----------------------+-----------------------+---------------------+---------------------+
# | BBW(Low)  | 0.9998473748473748     | 0.9995987158908507     | 0.9999113632334693    | 0.9984894259818732    | 0.07189901207464325 | 0.6729438893159109  |
# +-----------+------------------------+------------------------+-----------------------+-----------------------+---------------------+---------------------+
#
# CPT of RTT:
# +-------------+--------------------+-----------------------+-----------------------+----------------------+----------------------+---------------------+
# | BBW         | BBW(High)          | BBW(High)             | BBW(High)             | BBW(Low)             | BBW(Low)             | BBW(Low)            |
# +-------------+--------------------+-----------------------+-----------------------+----------------------+----------------------+---------------------+
# | TT          | TT(High)           | TT(Low)               | TT(Medium)            | TT(High)             | TT(Low)              | TT(Medium)          |
# +-------------+--------------------+-----------------------+-----------------------+----------------------+----------------------+---------------------+
# | RTT(High)   | 0.3333333333333333 | 0.0005906674542232724 | 0.0011723329425556862 | 0.7432413697490642   | 0.049942813572245524 | 0.35839791299010204 |
# +-------------+--------------------+-----------------------+-----------------------+----------------------+----------------------+---------------------+
# | RTT(Low)    | 0.3333333333333333 | 0.9988186650915535    | 0.9976553341148887    | 0.005684181339248578 | 0.6828059473884865   | 0.24944371978822985 |
# +-------------+--------------------+-----------------------+-----------------------+----------------------+----------------------+---------------------+
# | RTT(Medium) | 0.3333333333333333 | 0.0005906674542232724 | 0.0011723329425556862 | 0.2510744489116872   | 0.26725123903926806  | 0.392158367221668   |
# +-------------+--------------------+-----------------------+-----------------------+----------------------+----------------------+---------------------+
#
# CPT of RMIPS:
# +---------------+------------------------+----------------------+------------------------+---------------------+------------------------+------------------------+-----------------------+-----------------------+----------------------+
# | RTT           | RTT(High)              | RTT(High)            | RTT(High)              | RTT(Low)            | RTT(Low)               | RTT(Low)               | RTT(Medium)           | RTT(Medium)           | RTT(Medium)          |
# +---------------+------------------------+----------------------+------------------------+---------------------+------------------------+------------------------+-----------------------+-----------------------+----------------------+
# | TT            | TT(High)               | TT(Low)              | TT(Medium)             | TT(High)            | TT(Low)                | TT(Medium)             | TT(High)              | TT(Low)               | TT(Medium)           |
# +---------------+------------------------+----------------------+------------------------+---------------------+------------------------+------------------------+-----------------------+-----------------------+----------------------+
# | RMIPS(High)   | 0.5987320529554354     | 0.007518796992481204 | 0.4003851915257864     | 0.02325581395348838 | 0.00028710881424059715 | 0.00024372410431391662 | 0.6955322669608385    | 0.0014224751066856335 | 0.2505378447095638   |
# +---------------+------------------------+----------------------+------------------------+---------------------+------------------------+------------------------+-----------------------+-----------------------+----------------------+
# | RMIPS(Low)    | 0.00018646280067126608 | 0.007518796992481204 | 0.00021399529210357372 | 0.9534883720930234  | 0.9994257823715187     | 0.9995125517913721     | 0.30391616105901825   | 0.9971550497866289    | 0.7492665753960492   |
# +---------------+------------------------+----------------------+------------------------+---------------------+------------------------+------------------------+-----------------------+-----------------------+----------------------+
# | RMIPS(Medium) | 0.4010814842438933     | 0.9849624060150376   | 0.59940081318211       | 0.02325581395348838 | 0.00028710881424059715 | 0.00024372410431391662 | 0.0005515719801434088 | 0.0014224751066856335 | 0.000195579894386857 |
# +---------------+------------------------+----------------------+------------------------+---------------------+------------------------+------------------------+-----------------------+-----------------------+----------------------+
#
# CPT of RBW:
# +-----------+------------------------+----------------------+------------------------+----------------------+---------------------+---------------------+-----------------------+-----------------------+------------------------+
# | RTT       | RTT(High)              | RTT(High)            | RTT(High)              | RTT(Low)             | RTT(Low)            | RTT(Low)            | RTT(Medium)           | RTT(Medium)           | RTT(Medium)            |
# +-----------+------------------------+----------------------+------------------------+----------------------+---------------------+---------------------+-----------------------+-----------------------+------------------------+
# | TT        | TT(High)               | TT(Low)              | TT(Medium)             | TT(High)             | TT(Low)             | TT(Medium)          | TT(High)              | TT(Low)               | TT(Medium)             |
# +-----------+------------------------+----------------------+------------------------+----------------------+---------------------+---------------------+-----------------------+-----------------------+------------------------+
# | RBW(High) | 0.00018649757553151807 | 0.007575757575757577 | 0.00021404109589041095 | 0.9761904761904763   | 0.5143595634692706  | 0.7925402242808386  | 0.0005518763796909493 | 0.0014245014245014248 | 0.00019561815336463224 |
# +-----------+------------------------+----------------------+------------------------+----------------------+---------------------+---------------------+-----------------------+-----------------------+------------------------+
# | RBW(Low)  | 0.9998135024244684     | 0.9924242424242424   | 0.9997859589041096     | 0.023809523809523815 | 0.48564043653072947 | 0.20745977571916135 | 0.9994481236203091    | 0.9985754985754987    | 0.9998043818466353     |
# +-----------+------------------------+----------------------+------------------------+----------------------+---------------------+---------------------+-----------------------+-----------------------+------------------------+
#
# CPT of RET:
# +-----------+------------------------+-------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+
# | RMIPS     | RMIPS(High)            | RMIPS(High) | RMIPS(High)            | RMIPS(Low)            | RMIPS(Low)            | RMIPS(Low)            | RMIPS(Medium)         | RMIPS(Medium)        | RMIPS(Medium)        |
# +-----------+------------------------+-------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+
# | TT        | TT(High)               | TT(Low)     | TT(Medium)             | TT(High)              | TT(Low)               | TT(Medium)            | TT(High)              | TT(Low)              | TT(Medium)           |
# +-----------+------------------------+-------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+
# | RET(High) | 0.9997763864042933     | 0.5         | 0.9996827411167512     | 0.0016891891891891893 | 0.0002391200382592061 | 0.0001260716086737267 | 0.9995353159851301    | 0.9924242424242424   | 0.9996431120628122   |
# +-----------+------------------------+-------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+
# | RET(Low)  | 0.00022361359570661896 | 0.5         | 0.00031725888324873094 | 0.9983108108108107    | 0.9997608799617408    | 0.9998739283913263    | 0.0004646840148698885 | 0.007575757575757577 | 0.000356887937187723 |
# +-----------+------------------------+-------------+------------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+
#
# CPT of TT:
# +------------+----------+
# | TT(High)   | 0.283864 |
# +------------+----------+
# | TT(Low)    | 0.169704 |
# +------------+----------+
# | TT(Medium) | 0.546432 |
# +------------+----------+
